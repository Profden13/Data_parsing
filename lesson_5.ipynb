# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.9/272.9 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 7.3 MB/s eta 0:00:00
# ...

# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !scrapy startproject project_parser_hh
# Out:
# New Scrapy project 'project_parser_hh', using template directory '/usr/local/lib/python3.8/dist-packages/scrapy/templates/project', created in:
#     /content/project_parser_hh
#
# You can start your first spider with:
#     cd project_parser_hh
#     scrapy genspider example example.com

# %%
# %cd project_parser_hh
# Out:
# /content/project_parser_hh

# %%
# !scrapy genspider hh_ru hh.ru
# Out:
# Created spider 'hh_ru' using template 'basic' in module:
#   project_parser_hh.spiders.hh_ru

# %%
# !scrapy crawl hh_ru
# Out:
# 2023-03-06 14:22:13 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: project_parser_hh)
# 2023-03-06 14:22:14 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.10 (default, Nov 14 2022, 12:59:47) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.2, Platform Linux-5.10.147+-x86_64-with-glibc2.29
# 2023-03-06 14:22:14 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'project_parser_hh',
#  'DOWNLOAD_DELAY': 0.5,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'project_parser_hh.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['project_parser_hh.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
# ...

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'vacancies_python_hh']

# %%
db = client.vacancies_python_hh
print(db.list_collection_names())
# Out:
# ['hh_ru']

# %%
collection_vacancies_hh_ru = db.hh_ru

# %%
vacancies_hh_ru_list = list(collection_vacancies_hh_ru.find())

# %%
len(vacancies_hh_ru_list)
# Out:
# 276

# %%
vacancies_hh_ru_list[:10] # первые 10
# Out:
# [{'_id': ObjectId('6405f71ba00ab56d47000cbd'),
#   'name': 'Middle/Middle+Python разработчик',
#   'salary': ['от ',
#    '140\xa0000',
#    ' до ',
#    '220\xa0000',
#    ' ',
#    'руб.',
#    ' ',
#    'до вычета налогов'],
#   'url': 'https://spb.hh.ru/vacancy/77648093?from=vacancy_search_list&query=python'},
#  {'_id': ObjectId('6405f71ba00ab56d47000cbe'),
#   'name': 'Python Developer',
#   'salary': ['з/п не указана'],
#   'url': 'https://spb.hh.ru/vacancy/75546793?from=vacancy_search_list&query=python'},
#  {'_id': ObjectId('6405f71ca00ab56d47000cbf'),
#   'name': 'Программист Python',
#   'salary': ['от ',
#    '40\xa0000',
#    ' до ',
#    '150\xa0000',
#    ' ',
#    'руб.',
#    ' ',
#    'на руки'],
#   'url': 'https://spb.hh.ru/vacancy/76628647?from=vacancy_search_list&query=python'},
#  {'_id': ObjectId('6405f71ca00ab56d47000cc0'),
#   'name': 'Программист Python - FastAPI',
#   'salary': ['от ', '180\xa0000', ' ', 'руб.', ' ', 'на руки'],
# ...

# %%
# !scrapy genspider sj_ru superjob.ru
# Out:
# Created spider 'sj_ru' using template 'basic' in module:
#   project_parser_hh.spiders.sj_ru

# %%
import shutil
#shutil.make_archive('project_parser_hh', 'zip', 'project_parser_hh')

# %%
shutil.unpack_archive('project_parser_hh.zip', 'project_parser_hh', 'zip')
